# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv("../data/mental_health_burnout_prediction_dataset.csv")

# %%
connection = sqlite3.connect('burnout_database.db')

df.to_sql('burnout_data', connection, if_exists='replace', index=False)
connection.close()

# %%
connection = sqlite3.connect('burnout_database.db')

df_check = pd.read_sql('SELECT * FROM burnout_data', connection)
connection.close()
print(df_check.head())
# Out:
#    Person_ID   Age  Gender        Country         Occupation Education_Level  \
# 0          1  58.0    Male  United States  Marketing Manager         Diploma
# 1          2  24.0  Female       Pakistan         Freelancer        Bachelor
# 2          3  59.0    Male       Malaysia         Accountant             PhD
# 3          4  65.0   Other         Mexico               Chef          Master
# 4          5  64.0   Other          Japan             Farmer         Diploma
#
#   Employment_Status  Monthly_Income_USD  Work_Hours_Per_Week Remote_Work  ...  \
# 0          Employed              2786.0                   67      Hybrid  ...
# 1           Student              8027.0                   44      Hybrid  ...
# 2          Employed              3177.0                   60          No  ...
# 3     Self-Employed              4093.0                   25         Yes  ...
# 4           Student                 NaN                   52          No  ...
#
# ...
